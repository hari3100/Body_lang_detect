# %%
pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mediapipe
#   Using cached mediapipe-0.10.9-cp310-cp310-win_amd64.whl (50.5 MB)
# Requirement already satisfied: opencv-python in c:\users\asus\appdata\roaming\python\python310\site-packages (4.8.1.78)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (1.23.5)
# Collecting sounddevice>=0.4.4
#   Using cached sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (3.7.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from mediapipe) (23.5.26)
# Collecting protobuf<4,>=3.11
#   Using cached protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: absl-py in c:\users\asus\appdata\roaming\python\python310\site-packages (from mediapipe) (2.0.0)
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.8.1.78-cp37-abi3-win_amd64.whl (44.8 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Installing collected packages: protobuf, opencv-contrib-python, sounddevice, mediapipe
# Successfully installed mediapipe-0.10.9 opencv-contrib-python-4.8.1.78 protobuf-3.20.3 sounddevice-0.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 # Import opencv
import mediapipe as mp # Import mediapipe
import warnings
warnings.filterwarnings("ignore")

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %%
cap = cv2.VideoCapture(0)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Draw face landmarks and connections using mp_drawing
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.q, 
                                   mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                   mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                   )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                   mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                   mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                   )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                   mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                   mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                   )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                   mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                   mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                   )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %%
import csv
import os
import numpy as np
import pandas as pd

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
#with open('coords.csv', mode='w', newline='') as f:
#    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#    csv_writer.writerow(landmarks)

# %%
#class_name = "inappropriate"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            #with open('coords.csv', mode='a', newline='') as f:
                #csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                #csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0  Cheerful  0.527345  0.474855 -0.915747  0.999985  0.551102  0.407104
# 1  Cheerful  0.527036  0.474771 -0.849801  0.999983  0.551024  0.407063
# 2  Cheerful  0.526885  0.474705 -0.847417  0.999983  0.551021  0.407067
# 3  Cheerful  0.526857  0.474586 -0.846487  0.999982  0.551040  0.407065
# 4  Cheerful  0.526685  0.474671 -0.854432  0.999982  0.551060  0.407126
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.858705  0.999963  0.569700  ... -0.004335   0.0  0.586981  0.406959
# 1 -0.793048  0.999957  0.569682  ... -0.003494   0.0  0.586888  0.406344
# 2 -0.794759  0.999955  0.569677  ... -0.005064   0.0  0.590808  0.409575
# 3 -0.794788  0.999953  0.569693  ... -0.004728   0.0  0.589455  0.410338
# 4 -0.801415  0.999954  0.569792  ... -0.002796   0.0  0.588651  0.411344
#
#        z500  v500      x501      y501      z501  v501
# 0  0.015102   0.0  0.592076  0.400850  0.015880   0.0
# 1  0.015157   0.0  0.591791  0.400117  0.015915   0.0
# 2  0.013992   0.0  0.595765  0.403510  0.014712   0.0
# 3  0.013700   0.0  0.594503  0.403606  0.014465   0.0
# 4  0.016825   0.0  0.593666  0.405467  0.017654   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#               class        x1        y1        z1        v1        x2  \
# 1168  inappropriate  0.498639  0.489730 -0.673678  0.999990  0.517448
# 1169  inappropriate  0.497491  0.489548 -0.619484  0.999989  0.517126
# 1170  inappropriate  0.497186  0.488440 -0.622117  0.999989  0.517049
# 1171  inappropriate  0.497866  0.486627 -0.612614  0.999988  0.518392
# 1172  inappropriate  0.500858  0.481821 -0.610590  0.999987  0.521539
#
#             y2        z2        v2        x3  ...      z499  v499      x500  \
# 1168  0.440287 -0.633553  0.999978  0.532170  ...  0.003841   0.0  0.538760
# 1169  0.439743 -0.577816  0.999976  0.531946  ...  0.001354   0.0  0.542486
# 1170  0.438700 -0.587670  0.999975  0.531908  ...  0.004791   0.0  0.545080
# 1171  0.435895 -0.569508  0.999974  0.533586  ...  0.003993   0.0  0.554279
# 1172  0.432254 -0.568846  0.999971  0.536829  ...  0.002228   0.0  0.554291
#
#           y500      z500  v500      x501      y501      z501  v501
# 1168  0.431705  0.018773   0.0  0.542372  0.425448  0.019544   0.0
# 1169  0.427798  0.014959   0.0  0.545984  0.422202  0.015523   0.0
# 1170  0.428114  0.020041   0.0  0.548822  0.422078  0.020796   0.0
# 1171  0.429950  0.018945   0.0  0.557914  0.423974  0.019705   0.0
# 1172  0.427248  0.019138   0.0  0.557908  0.421189  0.020025   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='sad']
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 208   sad  0.581126  0.604052 -1.998444  0.999539  0.609213  0.524301
# 209   sad  0.582076  0.603920 -1.609706  0.999548  0.609318  0.524300
# 210   sad  0.582080  0.602203 -1.544457  0.999569  0.609164  0.523483
# 211   sad  0.582179  0.602086 -1.521564  0.999590  0.609118  0.523253
# 212   sad  0.581008  0.601843 -1.474586  0.999600  0.607847  0.523245
# ..    ...       ...       ...       ...       ...       ...       ...
# 516   sad  0.547471  0.511344 -0.964550  0.999632  0.565454  0.444998
# 517   sad  0.534301  0.503491 -1.043010  0.999667  0.552960  0.434718
# 518   sad  0.529656  0.499595 -1.064706  0.999699  0.549381  0.431576
# 519   sad  0.527649  0.494284 -0.990214  0.999727  0.547782  0.428525
# 520   sad  0.529336  0.495728 -0.796885  0.999751  0.547754  0.430937
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 208 -1.943587  0.998961  0.628772  ... -0.004055   0.0  0.644598  0.517735
# 209 -1.567361  0.998989  0.628813  ... -0.003889   0.0  0.644337  0.515111
# 210 -1.492534  0.999050  0.628608  ... -0.005582   0.0  0.644033  0.514040
# 211 -1.470793  0.999106  0.628573  ... -0.005630   0.0  0.643137  0.513377
# 212 -1.426505  0.999139  0.627692  ... -0.007004   0.0  0.644370  0.512832
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 516 -0.901137  0.999297  0.582300  ...  0.002726   0.0  0.599015  0.447625
# 517 -0.973714  0.999363  0.570552  ...  0.002347   0.0  0.588165  0.445285
# 518 -0.994462  0.999422  0.567242  ...  0.002208   0.0  0.590098  0.445896
# 519 -0.922067  0.999474  0.565472  ...  0.003421   0.0  0.586444  0.444960
# 520 -0.739620  0.999520  0.565169  ...  0.006995   0.0  0.590412  0.448447
#
#          z500  v500      x501      y501      z501  v501
# 208  0.022494   0.0  0.650281  0.510453  0.023441   0.0
# 209  0.023737   0.0  0.649646  0.508321  0.024722   0.0
# 210  0.019854   0.0  0.649258  0.506893  0.020644   0.0
# 211  0.019252   0.0  0.648383  0.506021  0.020027   0.0
# 212  0.019584   0.0  0.649760  0.505196  0.020504   0.0
# ..        ...   ...       ...       ...       ...   ...
# 516  0.030418   0.0  0.603779  0.440168  0.031860   0.0
# 517  0.030586   0.0  0.592421  0.437566  0.032168   0.0
# 518  0.030342   0.0  0.594358  0.438061  0.031918   0.0
# 519  0.030692   0.0  0.590424  0.437268  0.032305   0.0
# 520  0.036195   0.0  0.594546  0.440203  0.038064   0.0
#
# [313 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 869             angry
# 1048    inappropriate
# 294               sad
# 683         confident
# 1157    inappropriate
#             ...
# 226               sad
# 94           Cheerful
# 613         confident
# 199          Cheerful
# 488               sad
# Name: class, Length: 352, dtype: object

# %% [markdown]
# #### Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['angry', 'inappropriate', 'sad', 'confident', 'inappropriate',
#        'angry', 'sad', 'inappropriate', 'inappropriate', 'confident',
#        'inappropriate', 'angry', 'inappropriate', 'angry', 'sad', 'sad',
#        'angry', 'sad', 'angry', 'inappropriate', 'inappropriate', 'sad',
#        'sad', 'inappropriate', 'sad', 'inappropriate', 'confident',
#        'inappropriate', 'confident', 'sad', 'Cheerful', 'inappropriate',
#        'angry', 'sad', 'sad', 'angry', 'Cheerful', 'confident', 'sad',
#        'Cheerful', 'confident', 'Cheerful', 'inappropriate',
#        'inappropriate', 'inappropriate', 'confident', 'sad', 'Cheerful',
#        'sad', 'sad', 'inappropriate', 'confident', 'confident', 'angry',
#        'Cheerful', 'sad', 'angry', 'angry', 'confident', 'sad',
#        'inappropriate', 'angry', 'inappropriate', 'sad', 'Cheerful',
#        'sad', 'angry', 'sad', 'sad', 'Cheerful', 'angry', 'confident',
#        'sad', 'inappropriate', 'sad', 'confident', 'angry',
#        'inappropriate', 'confident', 'confident', 'sad', 'sad',
#        'confident', 'confident', 'Cheerful', 'Cheerful', 'sad', 'angry',
#        'inappropriate', 'angry', 'Cheerful', 'Cheerful', 'angry', 'angry',
#        'confident', 'Cheerful', 'Cheerful', 'Cheerful', 'confident',
#        'Cheerful', 'inappropriate', 'angry', 'angry', 'inappropriate',
#        'inappropriate', 'sad', 'sad', 'angry', 'inappropriate', 'sad',
#        'angry', 'confident', 'confident', 'sad', 'Cheerful',
#        'inappropriate', 'sad', 'sad', 'inappropriate', 'angry',
#        'Cheerful', 'sad', 'inappropriate', 'sad', 'sad', 'sad',
#        'confident', 'angry', 'sad', 'Cheerful', 'angry', 'Cheerful',
#        'inappropriate', 'inappropriate', 'sad', 'Cheerful',
#        'inappropriate', 'Cheerful', 'sad', 'confident', 'confident',
#        'Cheerful', 'sad', 'inappropriate', 'angry', 'Cheerful', 'angry',
#        'inappropriate', 'sad', 'Cheerful', 'inappropriate', 'Cheerful',
#        'sad', 'Cheerful', 'confident', 'inappropriate', 'inappropriate',
#        'angry', 'sad', 'Cheerful', 'angry', 'angry', 'sad', 'sad',
#        'Cheerful', 'inappropriate', 'confident', 'sad', 'inappropriate',
#        'sad', 'sad', 'angry', 'angry', 'sad', 'inappropriate', 'angry',
#        'inappropriate', 'sad', 'Cheerful', 'inappropriate', 'confident',
#        'sad', 'Cheerful', 'confident', 'confident', 'Cheerful',
#        'inappropriate', 'inappropriate', 'Cheerful', 'sad', 'sad',
#        'confident', 'confident', 'sad', 'angry', 'inappropriate', 'angry',
#        'sad', 'confident', 'Cheerful', 'angry', 'sad', 'inappropriate',
#        'sad', 'angry', 'sad', 'Cheerful', 'sad', 'sad', 'angry',
#        'Cheerful', 'confident', 'angry', 'angry', 'sad', 'Cheerful',
#        'Cheerful', 'angry', 'angry', 'inappropriate', 'inappropriate',
#        'sad', 'confident', 'Cheerful', 'confident', 'angry',
#        'inappropriate', 'sad', 'inappropriate', 'sad', 'sad', 'sad',
#        'inappropriate', 'sad', 'angry', 'Cheerful', 'angry', 'confident',
#        'confident', 'inappropriate', 'inappropriate', 'confident',
#        'confident', 'Cheerful', 'Cheerful', 'sad', 'inappropriate',
#        'inappropriate', 'Cheerful', 'angry', 'sad', 'angry', 'confident',
#        'confident', 'confident', 'angry', 'sad', 'inappropriate',
#        'Cheerful', 'inappropriate', 'Cheerful', 'angry', 'Cheerful',
#        'angry', 'angry', 'angry', 'angry', 'sad', 'confident',
#        'confident', 'angry', 'confident', 'angry', 'Cheerful', 'sad',
#        'sad', 'inappropriate', 'sad', 'confident', 'confident', 'sad',
#        'Cheerful', 'angry', 'inappropriate', 'sad', 'confident',
#        'Cheerful', 'angry', 'inappropriate', 'sad', 'angry', 'confident',
#        'sad', 'confident', 'inappropriate', 'sad', 'inappropriate', 'sad',
#        'Cheerful', 'inappropriate', 'sad', 'confident', 'confident',
#        'inappropriate', 'sad', 'sad', 'inappropriate', 'confident',
#        'inappropriate', 'sad', 'inappropriate', 'sad', 'inappropriate',
#        'inappropriate', 'Cheerful', 'confident', 'inappropriate', 'sad',
#        'angry', 'angry', 'sad', 'Cheerful', 'sad', 'confident',
#        'Cheerful', 'inappropriate', 'Cheerful', 'Cheerful',
#        'inappropriate', 'confident', 'angry', 'inappropriate', 'Cheerful',
#        'Cheerful', 'inappropriate', 'angry', 'angry', 'inappropriate',
#        'Cheerful', 'confident', 'confident', 'inappropriate',
#        'inappropriate', 'angry', 'Cheerful', 'Cheerful', 'Cheerful',
#        'sad', 'Cheerful', 'confident', 'Cheerful', 'sad'], dtype='<U13')

# %% [markdown]
# #### Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9914772727272727

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['angry', 'inappropriate', 'sad', 'confident', 'inappropriate',
#        'angry', 'sad', 'inappropriate', 'inappropriate', 'confident',
#        'inappropriate', 'angry', 'inappropriate', 'angry', 'sad', 'sad',
#        'angry', 'sad', 'angry', 'inappropriate', 'inappropriate', 'sad',
#        'sad', 'inappropriate', 'sad', 'inappropriate', 'confident',
#        'inappropriate', 'confident', 'sad', 'Cheerful', 'inappropriate',
#        'angry', 'sad', 'sad', 'angry', 'Cheerful', 'confident', 'sad',
#        'Cheerful', 'confident', 'Cheerful', 'inappropriate',
#        'inappropriate', 'inappropriate', 'confident', 'sad', 'Cheerful',
#        'sad', 'sad', 'inappropriate', 'confident', 'confident', 'angry',
#        'Cheerful', 'sad', 'angry', 'angry', 'confident', 'sad',
#        'inappropriate', 'angry', 'inappropriate', 'sad', 'Cheerful',
#        'sad', 'angry', 'sad', 'sad', 'Cheerful', 'angry', 'confident',
#        'sad', 'inappropriate', 'sad', 'confident', 'angry',
#        'inappropriate', 'confident', 'confident', 'sad', 'sad',
#        'confident', 'confident', 'Cheerful', 'Cheerful', 'sad', 'angry',
#        'inappropriate', 'angry', 'Cheerful', 'Cheerful', 'angry', 'angry',
#        'confident', 'Cheerful', 'Cheerful', 'Cheerful', 'confident',
#        'Cheerful', 'inappropriate', 'angry', 'angry', 'inappropriate',
#        'inappropriate', 'sad', 'sad', 'angry', 'inappropriate', 'sad',
#        'angry', 'confident', 'confident', 'sad', 'Cheerful',
#        'inappropriate', 'sad', 'sad', 'inappropriate', 'angry',
#        'Cheerful', 'sad', 'inappropriate', 'sad', 'sad', 'sad',
#        'confident', 'angry', 'sad', 'Cheerful', 'angry', 'Cheerful',
#        'inappropriate', 'inappropriate', 'sad', 'Cheerful',
#        'inappropriate', 'Cheerful', 'sad', 'confident', 'confident',
#        'Cheerful', 'sad', 'inappropriate', 'angry', 'Cheerful', 'angry',
#        'inappropriate', 'sad', 'Cheerful', 'inappropriate', 'Cheerful',
#        'sad', 'Cheerful', 'confident', 'inappropriate', 'inappropriate',
#        'angry', 'sad', 'Cheerful', 'angry', 'angry', 'sad', 'sad',
#        'Cheerful', 'inappropriate', 'confident', 'sad', 'inappropriate',
#        'sad', 'sad', 'angry', 'angry', 'sad', 'inappropriate', 'angry',
#        'inappropriate', 'sad', 'Cheerful', 'inappropriate', 'confident',
#        'sad', 'Cheerful', 'confident', 'confident', 'Cheerful',
#        'inappropriate', 'inappropriate', 'Cheerful', 'sad', 'sad',
#        'confident', 'confident', 'sad', 'angry', 'inappropriate', 'angry',
#        'sad', 'confident', 'Cheerful', 'angry', 'sad', 'inappropriate',
#        'sad', 'angry', 'sad', 'Cheerful', 'sad', 'sad', 'angry',
#        'Cheerful', 'confident', 'angry', 'angry', 'sad', 'Cheerful',
#        'Cheerful', 'angry', 'angry', 'inappropriate', 'inappropriate',
#        'sad', 'confident', 'Cheerful', 'confident', 'angry',
#        'inappropriate', 'sad', 'inappropriate', 'sad', 'sad', 'sad',
#        'inappropriate', 'sad', 'angry', 'Cheerful', 'angry', 'confident',
#        'confident', 'inappropriate', 'inappropriate', 'confident',
#        'confident', 'Cheerful', 'Cheerful', 'sad', 'inappropriate',
#        'inappropriate', 'Cheerful', 'angry', 'sad', 'angry', 'confident',
#        'confident', 'confident', 'angry', 'sad', 'inappropriate',
#        'Cheerful', 'inappropriate', 'Cheerful', 'angry', 'Cheerful',
#        'angry', 'angry', 'angry', 'angry', 'sad', 'confident',
#        'confident', 'angry', 'confident', 'angry', 'Cheerful', 'sad',
#        'sad', 'inappropriate', 'sad', 'confident', 'confident', 'sad',
#        'Cheerful', 'angry', 'inappropriate', 'sad', 'confident',
#        'Cheerful', 'angry', 'inappropriate', 'sad', 'angry', 'confident',
#        'sad', 'confident', 'inappropriate', 'sad', 'inappropriate', 'sad',
#        'Cheerful', 'inappropriate', 'sad', 'confident', 'confident',
#        'inappropriate', 'sad', 'sad', 'inappropriate', 'confident',
#        'inappropriate', 'sad', 'inappropriate', 'sad', 'inappropriate',
#        'inappropriate', 'Cheerful', 'confident', 'inappropriate', 'sad',
#        'angry', 'angry', 'sad', 'Cheerful', 'sad', 'confident',
#        'Cheerful', 'inappropriate', 'Cheerful', 'Cheerful',
#        'inappropriate', 'confident', 'angry', 'inappropriate', 'Cheerful',
#        'Cheerful', 'inappropriate', 'angry', 'angry', 'inappropriate',
#        'Cheerful', 'confident', 'confident', 'inappropriate',
#        'inappropriate', 'angry', 'Cheerful', 'Cheerful', 'Cheerful',
#        'sad', 'Cheerful', 'confident', 'Cheerful', 'sad'], dtype=object)

# %%
y_test
# Out:
# 869             angry
# 1048    inappropriate
# 294               sad
# 683         confident
# 1157    inappropriate
#             ...
# 226               sad
# 94           Cheerful
# 613         confident
# 199          Cheerful
# 488               sad
# Name: class, Length: 352, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# ### Make Detections with Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Cheerful [0.78 0.   0.   0.2  0.02]
# Cheerful [0.93 0.   0.   0.07 0.  ]
# inappropriate [0.47 0.   0.   0.51 0.02]
# inappropriate [0.45 0.   0.   0.52 0.03]
# Cheerful [0.88 0.   0.   0.12 0.  ]
# Cheerful [0.96 0.   0.   0.04 0.  ]
# Cheerful [0.99 0.   0.   0.01 0.  ]
# Cheerful [1. 0. 0. 0. 0.]
# inappropriate [0.43 0.   0.   0.54 0.03]
# Cheerful [0.68 0.   0.   0.29 0.03]
# Cheerful [0.6  0.   0.   0.36 0.04]
# Cheerful [0.71 0.   0.   0.26 0.03]
# Cheerful [0.96 0.   0.   0.03 0.01]
# Cheerful [0.9  0.   0.   0.08 0.02]
# Cheerful [0.61 0.   0.   0.35 0.04]
# Cheerful [0.86 0.   0.   0.13 0.01]
# Cheerful [0.81 0.   0.   0.17 0.02]
# Cheerful [0.86 0.   0.   0.12 0.02]
# Cheerful [0.54 0.   0.   0.44 0.02]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [0.99 0.   0.01 0.   0.  ]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [0.86 0.13 0.   0.   0.01]
# Cheerful [0.84 0.14 0.01 0.   0.01]
# Cheerful [0.85 0.13 0.01 0.   0.01]
# Cheerful [0.83 0.14 0.02 0.   0.01]
# Cheerful [0.81 0.09 0.   0.   0.1 ]
# Cheerful [0.7  0.17 0.05 0.   0.08]
# Cheerful [0.63 0.17 0.01 0.   0.19]
# Cheerful [0.6  0.2  0.01 0.   0.19]
# Cheerful [0.61 0.22 0.03 0.   0.14]
# Cheerful [0.61 0.22 0.04 0.   0.13]
# Cheerful [0.62 0.24 0.02 0.   0.12]
# Cheerful [0.59 0.23 0.01 0.   0.17]
# Cheerful [0.55 0.24 0.03 0.   0.18]
# Cheerful [0.59 0.27 0.05 0.   0.09]
# Cheerful [0.62 0.25 0.06 0.   0.07]
# Cheerful [0.65 0.25 0.03 0.   0.07]
# Cheerful [0.63 0.25 0.05 0.   0.07]
# Cheerful [0.68 0.26 0.03 0.   0.03]
# Cheerful [0.67 0.25 0.05 0.   0.03]
# Cheerful [0.65 0.28 0.03 0.   0.04]
# Cheerful [0.67 0.25 0.01 0.   0.07]
# Cheerful [0.63 0.25 0.07 0.   0.05]
# Cheerful [0.58 0.29 0.06 0.   0.07]
# Cheerful [0.63 0.25 0.05 0.   0.07]
# Cheerful [0.7  0.2  0.06 0.   0.04]
# Cheerful [0.76 0.19 0.01 0.   0.04]
# Cheerful [0.78 0.17 0.03 0.   0.02]
# Cheerful [0.86 0.06 0.07 0.   0.01]
# Cheerful [0.85 0.07 0.07 0.   0.01]
# Cheerful [0.86 0.02 0.08 0.   0.04]
# Cheerful [0.84 0.07 0.06 0.   0.03]
# Cheerful [0.7  0.21 0.07 0.   0.02]
# Cheerful [0.71 0.24 0.03 0.   0.02]
# Cheerful [0.63 0.33 0.01 0.   0.03]
# angry [0.17 0.76 0.   0.   0.07]
# angry [0.05 0.84 0.   0.   0.11]
# angry [0.01 0.86 0.   0.   0.13]
# angry [0.01 0.86 0.   0.   0.13]
# angry [0.01 0.87 0.   0.   0.12]
# angry [0.02 0.87 0.   0.   0.11]
# angry [0.05 0.87 0.   0.   0.08]
# angry [0.02 0.89 0.   0.   0.09]
# angry [0.02 0.89 0.   0.   0.09]
# angry [0.03 0.85 0.   0.   0.12]
# angry [0.03 0.83 0.   0.   0.14]
# angry [0.02 0.85 0.   0.   0.13]
# angry [0.02 0.89 0.   0.   0.09]
# angry [0.03 0.89 0.   0.   0.08]
# angry [0.06 0.85 0.   0.   0.09]
# angry [0.05 0.82 0.   0.   0.13]
# angry [0.03 0.83 0.   0.   0.14]
# angry [0.06 0.85 0.   0.   0.09]
# angry [0.06 0.83 0.   0.   0.11]
# angry [0.06 0.85 0.   0.   0.09]
# angry [0.07 0.82 0.   0.   0.11]
# angry [0.08 0.79 0.   0.   0.13]
# angry [0.1  0.79 0.   0.   0.11]
# angry [0.08 0.82 0.   0.   0.1 ]
# angry [0.11 0.79 0.   0.   0.1 ]
# angry [0.11 0.75 0.   0.   0.14]
# angry [0.19 0.71 0.   0.   0.1 ]
# Cheerful [0.64 0.22 0.03 0.   0.11]
# Cheerful [0.95 0.   0.   0.   0.05]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [0.93 0.   0.06 0.01 0.  ]
# Cheerful [0.85 0.   0.11 0.02 0.02]
# Cheerful [0.64 0.   0.33 0.02 0.01]
# Cheerful [0.75 0.   0.2  0.03 0.02]
# Cheerful [0.67 0.   0.26 0.04 0.03]
# Cheerful [0.72 0.   0.27 0.   0.01]
# Cheerful [0.69 0.   0.24 0.04 0.03]
# Cheerful [0.54 0.   0.31 0.12 0.03]
# confident [0.39 0.   0.59 0.   0.02]
# Cheerful [0.6  0.   0.33 0.06 0.01]
# confident [0.41 0.   0.54 0.04 0.01]
# confident [0.44 0.   0.54 0.01 0.01]
# Cheerful [0.63 0.   0.33 0.04 0.  ]
# Cheerful [0.78 0.   0.19 0.03 0.  ]
# Cheerful [0.75 0.   0.2  0.05 0.  ]
# Cheerful [0.79 0.   0.2  0.01 0.  ]
# Cheerful [0.63 0.   0.35 0.02 0.  ]
# Cheerful [0.76 0.   0.21 0.03 0.  ]
# Cheerful [0.87 0.   0.13 0.   0.  ]
# Cheerful [0.57 0.   0.27 0.15 0.01]
# Cheerful [0.76 0.   0.22 0.02 0.  ]
# Cheerful [0.75 0.   0.22 0.03 0.  ]
# Cheerful [0.93 0.   0.07 0.   0.  ]
# Cheerful [0.9 0.  0.1 0.  0. ]
# Cheerful [0.87 0.   0.11 0.02 0.  ]
# Cheerful [0.71 0.   0.26 0.03 0.  ]
# Cheerful [0.73 0.   0.24 0.03 0.  ]
# Cheerful [0.65 0.   0.24 0.11 0.  ]
# Cheerful [0.77 0.   0.2  0.03 0.  ]
# Cheerful [0.88 0.   0.1  0.02 0.  ]
# inappropriate [0.16 0.   0.01 0.82 0.01]
# inappropriate [0.15 0.   0.   0.84 0.01]
# inappropriate [0.17 0.   0.   0.81 0.02]
# inappropriate [0.16 0.   0.   0.83 0.01]
# inappropriate [0.16 0.   0.   0.83 0.01]
# inappropriate [0.16 0.   0.   0.82 0.02]
# inappropriate [0.15 0.   0.   0.84 0.01]
# inappropriate [0.15 0.   0.   0.84 0.01]
# inappropriate [0.16 0.   0.   0.83 0.01]
# inappropriate [0.16 0.   0.   0.83 0.01]
# inappropriate [0.16 0.   0.   0.83 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.18 0.   0.   0.82 0.  ]
# inappropriate [0.19 0.   0.   0.81 0.  ]
# inappropriate [0.33 0.   0.02 0.63 0.02]
# inappropriate [0.3  0.   0.04 0.65 0.01]
# inappropriate [0.29 0.   0.03 0.67 0.01]
# inappropriate [0.21 0.   0.02 0.76 0.01]
# inappropriate [0.27 0.   0.02 0.71 0.  ]
# inappropriate [0.27 0.   0.03 0.7  0.  ]
# inappropriate [0.31 0.   0.02 0.66 0.01]
# inappropriate [0.32 0.   0.02 0.66 0.  ]
# inappropriate [0.23 0.   0.   0.76 0.01]
# inappropriate [0.21 0.   0.   0.76 0.03]
# inappropriate [0.39 0.   0.   0.59 0.02]
# inappropriate [0.19 0.   0.01 0.79 0.01]
# inappropriate [0.46 0.   0.01 0.52 0.01]
# inappropriate [0.4  0.   0.   0.59 0.01]
# inappropriate [0.3  0.   0.01 0.66 0.03]
# Cheerful [0.98 0.   0.   0.02 0.  ]
# Cheerful [0.97 0.   0.   0.03 0.  ]
# Cheerful [0.78 0.   0.   0.22 0.  ]
# Cheerful [0.93 0.   0.   0.06 0.01]
# Cheerful [0.83 0.   0.   0.16 0.01]
# Cheerful [0.96 0.   0.02 0.02 0.  ]
# Cheerful [0.81 0.   0.02 0.15 0.02]
# Cheerful [0.77 0.   0.01 0.2  0.02]
# Cheerful [0.76 0.   0.01 0.21 0.02]
# Cheerful [0.95 0.   0.01 0.03 0.01]
# inappropriate [0.34 0.   0.   0.63 0.03]
# Cheerful [0.71 0.   0.   0.28 0.01]
# Cheerful [0.71 0.   0.   0.28 0.01]
# inappropriate [0.46 0.   0.   0.53 0.01]
# inappropriate [0.34 0.   0.   0.66 0.  ]
# Cheerful [0.65 0.   0.   0.34 0.01]
# inappropriate [0.24 0.   0.   0.74 0.02]
# Cheerful [0.86 0.   0.   0.14 0.  ]
# Cheerful [0.99 0.   0.   0.01 0.  ]
# Cheerful [0.87 0.   0.03 0.1  0.  ]
# Cheerful [0.71 0.   0.   0.28 0.01]
# inappropriate [0.32 0.   0.   0.68 0.  ]
# Cheerful [0.97 0.   0.   0.03 0.  ]
# Cheerful [0.84 0.   0.   0.16 0.  ]
# Cheerful [0.93 0.   0.   0.06 0.01]
# Cheerful [0.93 0.   0.   0.07 0.  ]
# Cheerful [0.93 0.   0.01 0.06 0.  ]
# Cheerful [0.72 0.   0.   0.28 0.  ]
# Cheerful [0.83 0.   0.01 0.16 0.  ]
# Cheerful [0.95 0.   0.   0.04 0.01]
# inappropriate [0.4  0.   0.   0.59 0.01]
# Cheerful [0.58 0.   0.   0.41 0.01]
# Cheerful [0.95 0.   0.   0.05 0.  ]
# Cheerful [0.91 0.   0.   0.09 0.  ]
# inappropriate [0.27 0.   0.01 0.7  0.02]
# Cheerful [0.99 0.   0.   0.01 0.  ]
# Cheerful [0.74 0.   0.01 0.24 0.01]
# Cheerful [0.81 0.   0.02 0.17 0.  ]
# Cheerful [0.77 0.   0.03 0.2  0.  ]
# inappropriate [0.37 0.   0.06 0.56 0.01]
# inappropriate [0.24 0.   0.01 0.75 0.  ]
# inappropriate [0.19 0.   0.   0.8  0.01]
# inappropriate [0.22 0.   0.   0.76 0.02]
# inappropriate [0.22 0.   0.   0.76 0.02]
# inappropriate [0.36 0.   0.   0.63 0.01]
# inappropriate [0.2  0.   0.   0.78 0.02]
# inappropriate [0.25 0.   0.   0.75 0.  ]
# Cheerful [0.59 0.   0.08 0.33 0.  ]
# inappropriate [0.32 0.   0.07 0.61 0.  ]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.21 0.   0.   0.76 0.03]
# inappropriate [0.26 0.   0.01 0.72 0.01]
# inappropriate [0.2  0.   0.   0.77 0.03]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.21 0.   0.   0.79 0.  ]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.3  0.   0.03 0.66 0.01]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.2 0.  0.  0.8 0. ]
# inappropriate [0.19 0.   0.   0.8  0.01]
# inappropriate [0.23 0.   0.01 0.76 0.  ]
# inappropriate [0.19 0.   0.   0.8  0.01]
# inappropriate [0.2  0.   0.   0.78 0.02]
# inappropriate [0.24 0.   0.   0.75 0.01]
# inappropriate [0.2  0.   0.   0.78 0.02]
# inappropriate [0.34 0.   0.04 0.62 0.  ]
# inappropriate [0.21 0.   0.   0.78 0.01]
# inappropriate [0.21 0.   0.01 0.77 0.01]
# inappropriate [0.19 0.   0.   0.8  0.01]
# inappropriate [0.22 0.   0.01 0.76 0.01]
# inappropriate [0.21 0.   0.   0.78 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.24 0.   0.   0.76 0.  ]
# inappropriate [0.31 0.   0.01 0.68 0.  ]
# inappropriate [0.41 0.   0.08 0.5  0.01]
# inappropriate [0.19 0.   0.   0.8  0.01]
# Cheerful [0.59 0.   0.02 0.38 0.01]
# inappropriate [0.29 0.   0.01 0.7  0.  ]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.18 0.   0.   0.81 0.01]
# inappropriate [0.21 0.   0.   0.77 0.02]
# inappropriate [0.19 0.   0.   0.8  0.01]
# inappropriate [0.22 0.   0.   0.78 0.  ]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.22 0.   0.01 0.76 0.01]
# inappropriate [0.19 0.   0.   0.8  0.01]
# inappropriate [0.21 0.   0.01 0.77 0.01]
# inappropriate [0.22 0.   0.01 0.76 0.01]
# inappropriate [0.21 0.   0.01 0.77 0.01]
# inappropriate [0.19 0.   0.   0.8  0.01]
# inappropriate [0.21 0.   0.   0.79 0.  ]
# inappropriate [0.17 0.   0.   0.82 0.01]
# inappropriate [0.25 0.   0.   0.73 0.02]
# inappropriate [0.22 0.   0.   0.74 0.04]
# inappropriate [0.34 0.   0.   0.62 0.04]
# inappropriate [0.29 0.03 0.07 0.51 0.1 ]
# sad [0.24 0.27 0.05 0.06 0.38]
# sad [0.07 0.38 0.03 0.04 0.48]
# angry [0.08 0.46 0.05 0.04 0.37]
# angry [0.07 0.52 0.03 0.04 0.34]
# angry [0.06 0.53 0.04 0.04 0.33]
# angry [0.05 0.52 0.02 0.04 0.37]
# angry [0.04 0.52 0.02 0.04 0.38]
# angry [0.05 0.51 0.02 0.04 0.38]
# angry [0.05 0.57 0.01 0.04 0.33]
# angry [0.05 0.58 0.01 0.02 0.34]
# angry [0.05 0.53 0.03 0.04 0.35]
# angry [0.04 0.51 0.02 0.03 0.4 ]
# angry [0.05 0.6  0.   0.   0.35]
# angry [0.04 0.6  0.   0.   0.36]
# angry [0.04 0.63 0.   0.   0.33]
# angry [0.04 0.64 0.   0.   0.32]
# angry [0.04 0.63 0.   0.   0.33]
# angry [0.05 0.58 0.   0.   0.37]
# angry [0.05 0.63 0.   0.   0.32]
# angry [0.04 0.63 0.   0.   0.33]
# angry [0.02 0.69 0.   0.   0.29]
# angry [0.01 0.67 0.   0.   0.32]
# angry [0.01 0.7  0.   0.   0.29]
# angry [0.01 0.72 0.   0.   0.27]
# angry [0.02 0.74 0.   0.   0.24]
# angry [0.02 0.65 0.   0.   0.33]
# angry [0.01 0.68 0.   0.   0.31]
# angry [0.03 0.67 0.   0.   0.3 ]
# angry [0.05 0.63 0.   0.   0.32]
# angry [0.05 0.63 0.   0.   0.32]
# angry [0.06 0.61 0.   0.   0.33]
# angry [0.05 0.62 0.   0.   0.33]
# angry [0.05 0.65 0.   0.   0.3 ]
# angry [0.05 0.6  0.   0.   0.35]
# angry [0.04 0.62 0.   0.   0.34]
# angry [0.03 0.63 0.   0.   0.34]
# angry [0.01 0.65 0.   0.   0.34]
# angry [0.01 0.88 0.   0.   0.11]
# angry [0.06 0.55 0.   0.   0.39]
# angry [0.06 0.6  0.   0.   0.34]
# angry [0.05 0.58 0.   0.01 0.36]
# angry [0.02 0.74 0.   0.   0.24]
# angry [0.05 0.6  0.   0.   0.35]
# angry [0.06 0.58 0.   0.   0.36]
# angry [0.06 0.58 0.   0.   0.36]
# angry [0.06 0.57 0.   0.   0.37]
# angry [0.07 0.57 0.   0.   0.36]
# angry [0.08 0.6  0.   0.   0.32]
# angry [0.06 0.6  0.   0.   0.34]
# angry [0.07 0.57 0.   0.   0.36]
# angry [0.05 0.57 0.   0.01 0.37]
# angry [0.05 0.6  0.   0.   0.35]
# angry [0.05 0.61 0.   0.   0.34]
# angry [0.05 0.59 0.   0.   0.36]
# angry [0.05 0.58 0.   0.01 0.36]
# angry [0.05 0.57 0.   0.01 0.37]
# angry [0.06 0.58 0.   0.   0.36]
# angry [0.06 0.52 0.   0.03 0.39]
# angry [0.05 0.57 0.   0.01 0.37]
# angry [0.05 0.52 0.   0.02 0.41]
# angry [0.05 0.46 0.02 0.03 0.44]
# angry [0.04 0.47 0.02 0.03 0.44]
# angry [0.06 0.49 0.02 0.03 0.4 ]
# angry [0.05 0.47 0.02 0.03 0.43]
# angry [0.06 0.51 0.   0.03 0.4 ]
# angry [0.04 0.47 0.02 0.03 0.44]
# angry [0.05 0.47 0.02 0.03 0.43]
# angry [0.04 0.48 0.01 0.04 0.43]
# sad [0.22 0.23 0.04 0.06 0.45]
# sad [0.25 0.13 0.04 0.28 0.3 ]
# inappropriate [0.35 0.03 0.02 0.46 0.14]
# sad [0.25 0.11 0.02 0.24 0.38]
# sad [0.2  0.15 0.01 0.15 0.49]
# sad [0.19 0.15 0.01 0.1  0.55]
# sad [0.2  0.19 0.03 0.06 0.52]
# sad [0.19 0.23 0.02 0.05 0.51]
# sad [0.16 0.25 0.02 0.04 0.53]
# sad [0.14 0.26 0.02 0.04 0.54]
# sad [0.11 0.28 0.02 0.04 0.55]
# sad [0.04 0.38 0.02 0.04 0.52]
# sad [0.05 0.37 0.02 0.04 0.52]
# sad [0.06 0.37 0.01 0.04 0.52]
# sad [0.04 0.32 0.02 0.03 0.59]
# sad [0.05 0.33 0.   0.04 0.58]
# sad [0.06 0.34 0.   0.03 0.57]
# sad [0.06 0.33 0.   0.04 0.57]
# sad [0.04 0.36 0.02 0.04 0.54]
# sad [0.07 0.4  0.   0.01 0.52]
# sad [0.17 0.28 0.   0.02 0.53]
# sad [0.22 0.22 0.   0.04 0.52]
# sad [0.21 0.22 0.03 0.03 0.51]
# sad [0.23 0.26 0.   0.   0.51]
# sad [0.19 0.29 0.   0.   0.52]
# sad [0.26 0.33 0.   0.   0.41]
# sad [0.28 0.34 0.   0.   0.38]
# sad [0.25 0.35 0.   0.   0.4 ]
# sad [0.28 0.28 0.   0.   0.44]
# sad [0.25 0.35 0.   0.   0.4 ]
# sad [0.17 0.41 0.   0.   0.42]
# angry [0.14 0.47 0.   0.   0.39]
# angry [0.22 0.45 0.   0.   0.33]
# angry [0.17 0.48 0.   0.   0.35]
# angry [0.21 0.43 0.   0.   0.36]
# angry [0.2  0.43 0.   0.   0.37]
# angry [0.18 0.47 0.   0.   0.35]
# angry [0.16 0.44 0.   0.   0.4 ]
# angry [0.15 0.44 0.   0.   0.41]
# angry [0.15 0.45 0.   0.   0.4 ]
# sad [0.15 0.41 0.   0.   0.44]
# sad [0.15 0.36 0.   0.   0.49]
# angry [0.14 0.44 0.   0.   0.42]
# sad [0.16 0.39 0.   0.   0.45]
# angry [0.19 0.41 0.   0.   0.4 ]
# sad [0.22 0.34 0.   0.   0.44]
# angry [0.2 0.4 0.  0.  0.4]
# angry [0.17 0.43 0.   0.   0.4 ]
# angry [0.15 0.48 0.   0.   0.37]
# angry [0.14 0.49 0.   0.   0.37]
# angry [0.19 0.42 0.   0.   0.39]
# angry [0.17 0.48 0.   0.   0.35]
# angry [0.17 0.47 0.   0.   0.36]
# angry [0.18 0.41 0.   0.   0.41]
# sad [0.19 0.35 0.   0.   0.46]
# sad [0.18 0.25 0.   0.02 0.55]
# sad [0.2  0.25 0.   0.01 0.54]
# sad [0.25 0.18 0.   0.02 0.55]
# sad [0.17 0.1  0.01 0.05 0.67]
# sad [0.16 0.12 0.02 0.06 0.64]
# sad [0.17 0.08 0.02 0.07 0.66]
# sad [0.19 0.05 0.02 0.07 0.67]
# sad [0.16 0.05 0.02 0.07 0.7 ]
# sad [0.14 0.06 0.01 0.07 0.72]
# sad [0.21 0.05 0.03 0.13 0.58]
# sad [0.25 0.08 0.02 0.12 0.53]
# sad [0.24 0.06 0.03 0.15 0.52]
# sad [0.22 0.06 0.03 0.21 0.48]
# sad [0.21 0.08 0.02 0.14 0.55]
# sad [0.16 0.05 0.01 0.12 0.66]
# sad [0.21 0.09 0.02 0.12 0.56]
# sad [0.16 0.06 0.02 0.09 0.67]
# sad [0.17 0.09 0.02 0.09 0.63]
# sad [0.21 0.07 0.02 0.07 0.63]
# sad [0.17 0.09 0.02 0.1  0.62]
# sad [0.18 0.09 0.02 0.14 0.57]
# sad [0.2  0.09 0.02 0.13 0.56]
# sad [0.18 0.1  0.02 0.09 0.61]
# sad [0.2  0.08 0.03 0.13 0.56]
# sad [0.23 0.1  0.03 0.18 0.46]
# sad [0.23 0.1  0.03 0.18 0.46]
# sad [0.24 0.08 0.03 0.19 0.46]
# sad [0.24 0.07 0.03 0.22 0.44]
# sad [0.21 0.09 0.03 0.2  0.47]
# sad [0.23 0.12 0.04 0.17 0.44]
# sad [0.28 0.08 0.04 0.2  0.4 ]
# sad [0.23 0.07 0.03 0.22 0.45]
# sad [0.23 0.11 0.03 0.22 0.41]
# sad [0.26 0.1  0.04 0.21 0.39]
# sad [0.23 0.1  0.03 0.21 0.43]
# sad [0.23 0.07 0.03 0.23 0.44]
# sad [0.24 0.06 0.03 0.22 0.45]
# sad [0.25 0.07 0.04 0.23 0.41]
# sad [0.24 0.06 0.04 0.27 0.39]
# inappropriate [0.25 0.04 0.05 0.36 0.3 ]
# inappropriate [0.35 0.   0.   0.56 0.09]
# inappropriate [0.27 0.   0.   0.68 0.05]
# inappropriate [0.17 0.   0.   0.8  0.03]
# confident [0.26 0.01 0.37 0.3  0.06]
# confident [0.34 0.02 0.48 0.13 0.03]
# confident [0.22 0.   0.41 0.28 0.09]
# confident [0.28 0.01 0.48 0.17 0.06]
# confident [0.31 0.02 0.65 0.01 0.01]
# confident [0.31 0.03 0.65 0.01 0.  ]
# confident [0.29 0.04 0.65 0.01 0.01]
# confident [0.33 0.04 0.52 0.07 0.04]
# confident [0.33 0.08 0.55 0.   0.04]
# confident [0.28 0.07 0.59 0.   0.06]
# confident [0.34 0.11 0.42 0.05 0.08]
# confident [0.35 0.07 0.49 0.03 0.06]
# confident [0.28 0.14 0.52 0.   0.06]
# confident [0.27 0.13 0.55 0.   0.05]
# confident [0.26 0.14 0.54 0.   0.06]
# confident [0.23 0.16 0.56 0.01 0.04]
# confident [0.22 0.16 0.55 0.01 0.06]
# confident [0.24 0.15 0.52 0.01 0.08]
# confident [0.22 0.17 0.55 0.01 0.05]
# confident [0.22 0.17 0.56 0.   0.05]
# confident [0.19 0.17 0.56 0.   0.08]
# confident [0.22 0.19 0.54 0.01 0.04]
# confident [0.19 0.16 0.56 0.01 0.08]
# confident [0.21 0.17 0.55 0.   0.07]
# confident [0.18 0.23 0.49 0.01 0.09]
# confident [0.19 0.24 0.47 0.01 0.09]
# confident [0.19 0.2  0.53 0.01 0.07]
# Cheerful [0.45 0.28 0.11 0.   0.16]
# Cheerful [0.37 0.33 0.12 0.01 0.17]
# angry [0.13 0.44 0.04 0.04 0.35]
# angry [0.06 0.51 0.03 0.03 0.37]
# angry [0.07 0.53 0.01 0.03 0.36]
# angry [0.06 0.49 0.03 0.03 0.39]
# angry [0.05 0.48 0.02 0.03 0.42]
# angry [0.06 0.49 0.01 0.03 0.41]
# angry [0.05 0.51 0.02 0.03 0.39]
# angry [0.04 0.5  0.   0.03 0.43]
# angry [0.04 0.48 0.   0.03 0.45]
# sad [0.04 0.45 0.02 0.03 0.46]
# angry [0.04 0.49 0.   0.02 0.45]
# angry [0.05 0.47 0.03 0.03 0.42]
# angry [0.04 0.47 0.03 0.03 0.43]
# sad [0.04 0.44 0.02 0.03 0.47]
# sad [0.04 0.38 0.02 0.03 0.53]
# sad [0.04 0.41 0.02 0.03 0.5 ]
# sad [0.04 0.42 0.02 0.03 0.49]
# sad [0.04 0.37 0.02 0.03 0.54]
# sad [0.04 0.41 0.02 0.03 0.5 ]
# sad [0.04 0.38 0.02 0.03 0.53]
# sad [0.04 0.4  0.02 0.03 0.51]
# sad [0.04 0.44 0.02 0.03 0.47]
# sad [0.03 0.39 0.02 0.03 0.53]
# sad [0.03 0.4  0.02 0.03 0.52]
# angry [0.03 0.51 0.   0.   0.46]
# angry [0.   0.85 0.   0.   0.15]
# angry [0.   0.85 0.01 0.   0.14]
# angry [0.   0.84 0.02 0.   0.14]
# angry [0.   0.85 0.01 0.   0.14]
# angry [0.   0.83 0.   0.   0.17]
# angry [0.  0.8 0.  0.  0.2]
# angry [0.   0.69 0.   0.   0.31]
# angry [0.   0.69 0.02 0.   0.29]
# angry [0.   0.69 0.02 0.   0.29]
# angry [0.01 0.67 0.   0.   0.32]
# angry [0.01 0.68 0.   0.   0.31]
# angry [0.   0.69 0.   0.   0.31]
# angry [0.   0.72 0.01 0.   0.27]
# angry [0.   0.73 0.   0.   0.27]
# angry [0.  0.7 0.  0.  0.3]
# angry [0.   0.67 0.   0.   0.33]
# angry [0.03 0.57 0.   0.   0.4 ]
# sad [0.03 0.45 0.02 0.03 0.47]
# sad [0.05 0.39 0.03 0.04 0.49]
# sad [0.15 0.24 0.07 0.06 0.48]
# sad [0.15 0.24 0.07 0.09 0.45]
# sad [0.15 0.22 0.07 0.09 0.47]
# sad [0.15 0.23 0.07 0.07 0.48]
# sad [0.14 0.24 0.07 0.07 0.48]
# sad [0.14 0.27 0.07 0.08 0.44]
# sad [0.14 0.27 0.07 0.08 0.44]
# sad [0.14 0.25 0.07 0.08 0.46]
# angry [0.13 0.51 0.   0.01 0.35]
# angry [0.   0.81 0.   0.   0.19]
# angry [0.01 0.7  0.   0.   0.29]
# angry [0.01 0.67 0.   0.   0.32]
# angry [0.01 0.66 0.   0.   0.33]
# angry [0.01 0.68 0.   0.   0.31]
# angry [0.01 0.7  0.   0.   0.29]
# angry [0.01 0.7  0.   0.   0.29]
# angry [0.01 0.71 0.   0.   0.28]
# angry [0.01 0.7  0.   0.   0.29]
# angry [0.01 0.71 0.   0.   0.28]
# angry [0.05 0.77 0.   0.   0.18]
# Cheerful [0.76 0.05 0.   0.   0.19]
# Cheerful [0.9  0.06 0.   0.   0.04]
# Cheerful [0.83 0.1  0.01 0.   0.06]
# Cheerful [0.93 0.   0.01 0.   0.06]
# Cheerful [0.92 0.01 0.01 0.   0.06]
# Cheerful [0.9  0.01 0.01 0.   0.08]
# Cheerful [0.9  0.02 0.01 0.   0.07]
# Cheerful [0.93 0.01 0.01 0.   0.05]
# Cheerful [0.93 0.01 0.01 0.   0.05]
# Cheerful [0.96 0.   0.01 0.   0.03]
# Cheerful [0.96 0.01 0.01 0.   0.02]
# Cheerful [0.96 0.   0.01 0.   0.03]
# Cheerful [0.94 0.01 0.01 0.   0.04]
# Cheerful [0.93 0.01 0.01 0.   0.05]
# Cheerful [0.91 0.02 0.01 0.   0.06]
# Cheerful [0.96 0.01 0.01 0.   0.02]
# Cheerful [0.92 0.02 0.01 0.   0.05]
# Cheerful [0.94 0.02 0.01 0.   0.03]
# Cheerful [0.91 0.02 0.01 0.   0.06]
# Cheerful [0.96 0.   0.01 0.   0.03]
# Cheerful [0.87 0.04 0.01 0.   0.08]
# Cheerful [0.94 0.01 0.01 0.   0.04]
# Cheerful [0.9  0.03 0.01 0.   0.06]
# Cheerful [0.89 0.02 0.01 0.   0.08]
# Cheerful [0.85 0.04 0.01 0.   0.1 ]
# Cheerful [0.92 0.01 0.01 0.   0.06]
# Cheerful [0.91 0.01 0.01 0.   0.07]
# Cheerful [0.85 0.04 0.01 0.   0.1 ]
# Cheerful [0.92 0.01 0.01 0.   0.06]
# Cheerful [0.93 0.01 0.01 0.   0.05]
# Cheerful [0.97 0.   0.01 0.   0.02]
# Cheerful [0.97 0.   0.01 0.   0.02]
# Cheerful [0.97 0.   0.01 0.   0.02]
# Cheerful [0.94 0.   0.01 0.03 0.02]
# Cheerful [0.64 0.   0.04 0.24 0.08]
# inappropriate [0.22 0.   0.   0.73 0.05]
# inappropriate [0.22 0.   0.01 0.73 0.04]
# inappropriate [0.2  0.   0.   0.77 0.03]
# inappropriate [0.21 0.   0.   0.76 0.03]
# inappropriate [0.21 0.   0.   0.76 0.03]
# inappropriate [0.22 0.   0.   0.74 0.04]
# inappropriate [0.32 0.   0.04 0.58 0.06]
# Cheerful [0.36 0.   0.16 0.36 0.12]
# Cheerful [0.38 0.   0.17 0.34 0.11]
# Cheerful [0.41 0.   0.14 0.28 0.17]
# Cheerful [0.32 0.02 0.18 0.32 0.16]
# inappropriate [0.29 0.02 0.2  0.32 0.17]
# Cheerful [0.34 0.06 0.14 0.25 0.21]
# Cheerful [0.3  0.13 0.11 0.2  0.26]
# sad [0.22 0.17 0.09 0.16 0.36]
# sad [0.21 0.2  0.07 0.1  0.42]
# sad [0.25 0.21 0.05 0.05 0.44]
# sad [0.25 0.21 0.05 0.03 0.46]
# sad [0.19 0.2  0.07 0.07 0.47]
# sad [0.23 0.18 0.05 0.07 0.47]
# sad [0.26 0.19 0.04 0.04 0.47]
# Cheerful [0.67 0.11 0.03 0.03 0.16]
# Cheerful [0.76 0.01 0.04 0.11 0.08]
# Cheerful [0.78 0.01 0.04 0.1  0.07]
# Cheerful [0.74 0.   0.04 0.15 0.07]
# Cheerful [0.83 0.01 0.02 0.08 0.06]
# Cheerful [0.96 0.   0.01 0.01 0.02]
# Cheerful [0.96 0.   0.01 0.01 0.02]
# Cheerful [0.9  0.   0.01 0.06 0.03]
# inappropriate [0.32 0.   0.01 0.58 0.09]
# Cheerful [0.72 0.   0.01 0.25 0.02]
# Cheerful [0.5  0.   0.11 0.32 0.07]
# Cheerful [0.54 0.   0.14 0.29 0.03]
# Cheerful [0.56 0.   0.26 0.14 0.04]
# Cheerful [0.45 0.   0.25 0.23 0.07]
# Cheerful [0.34 0.   0.27 0.29 0.1 ]
# Cheerful [0.65 0.   0.28 0.03 0.04]
# Cheerful [0.76 0.   0.19 0.01 0.04]
# Cheerful [0.73 0.   0.21 0.02 0.04]
# Cheerful [0.52 0.   0.44 0.01 0.03]
# Cheerful [0.43 0.   0.24 0.26 0.07]
# Cheerful [0.68 0.   0.25 0.04 0.03]
# Cheerful [0.57 0.   0.28 0.12 0.03]
# Cheerful [0.48 0.   0.32 0.16 0.04]
# Cheerful [0.48 0.   0.29 0.18 0.05]
# Cheerful [0.64 0.   0.31 0.03 0.02]
# confident [0.32 0.01 0.45 0.18 0.04]
# Cheerful [0.62 0.02 0.28 0.05 0.03]
# Cheerful [0.45 0.01 0.28 0.17 0.09]
# Cheerful [0.62 0.02 0.26 0.06 0.04]
# Cheerful [0.57 0.02 0.3  0.06 0.05]
# Cheerful [0.41 0.01 0.36 0.15 0.07]
# confident [0.38 0.02 0.5  0.06 0.04]
# Cheerful [0.65 0.11 0.14 0.01 0.09]
# Cheerful [0.46 0.01 0.27 0.18 0.08]
# Cheerful [0.42 0.02 0.39 0.12 0.05]
# Cheerful [0.42 0.07 0.41 0.03 0.07]
# Cheerful [0.5  0.05 0.33 0.04 0.08]
# Cheerful [0.52 0.1  0.28 0.   0.1 ]
# Cheerful [0.55 0.08 0.28 0.   0.09]
# Cheerful [0.5  0.11 0.26 0.01 0.12]
# Cheerful [0.5  0.11 0.27 0.02 0.1 ]
# Cheerful [0.65 0.12 0.15 0.   0.08]
# Cheerful [0.68 0.1  0.11 0.02 0.09]
# Cheerful [0.63 0.14 0.1  0.01 0.12]
# Cheerful [0.72 0.11 0.06 0.01 0.1 ]
# Cheerful [0.78 0.07 0.05 0.   0.1 ]
# Cheerful [0.91 0.   0.06 0.   0.03]
# Cheerful [0.98 0.   0.   0.   0.02]
# Cheerful [0.99 0.   0.   0.01 0.  ]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [1. 0. 0. 0. 0.]
# Cheerful [0.99 0.   0.   0.01 0.  ]
# Cheerful [0.98 0.   0.   0.01 0.01]
# Cheerful [0.96 0.   0.   0.03 0.01]
# Cheerful [0.76 0.   0.2  0.04 0.  ]
# confident [0.19 0.   0.44 0.37 0.  ]
# confident [0.25 0.   0.41 0.34 0.  ]
# confident [0.25 0.   0.4  0.32 0.03]
# confident [0.41 0.   0.55 0.04 0.  ]
# confident [0.43 0.   0.55 0.02 0.  ]
# Cheerful [0.36 0.   0.31 0.28 0.05]
# confident [0.35 0.   0.44 0.19 0.02]
# confident [0.29 0.   0.5  0.19 0.02]
# confident [0.38 0.   0.47 0.15 0.  ]
# Cheerful [0.67 0.   0.27 0.05 0.01]
# confident [0.38 0.   0.47 0.15 0.  ]
# confident [0.29 0.   0.39 0.29 0.03]
# confident [0.32 0.   0.63 0.05 0.  ]
# Cheerful [0.59 0.   0.38 0.03 0.  ]
# confident [0.45 0.   0.53 0.02 0.  ]
# confident [0.45 0.   0.55 0.   0.  ]
# Cheerful [0.5  0.   0.47 0.03 0.  ]
# confident [0.41 0.   0.58 0.01 0.  ]
# confident [0.46 0.   0.53 0.01 0.  ]
# confident [0.43 0.   0.57 0.   0.  ]
# Cheerful [0.52 0.   0.46 0.02 0.  ]
# Cheerful [0.71 0.   0.27 0.02 0.  ]
# confident [0.44 0.   0.55 0.01 0.  ]
# Cheerful [0.64 0.   0.33 0.03 0.  ]
# confident [0.41 0.   0.55 0.04 0.  ]
# confident [0.45 0.   0.55 0.   0.  ]
# Cheerful [0.72 0.   0.23 0.05 0.  ]
# Cheerful [0.55 0.   0.36 0.08 0.01]
# Cheerful [0.92 0.   0.07 0.01 0.  ]
# Cheerful [0.82 0.01 0.15 0.02 0.  ]
# Cheerful [0.84 0.01 0.13 0.02 0.  ]
# Cheerful [0.88 0.01 0.05 0.05 0.01]
# Cheerful [0.97 0.   0.01 0.02 0.  ]
# Cheerful [0.99 0.   0.   0.01 0.  ]
# Cheerful [0.99 0.   0.   0.01 0.  ]
# Cheerful [0.99 0.   0.   0.01 0.  ]
# Cheerful [0.84 0.14 0.   0.01 0.01]
# Cheerful [0.95 0.02 0.02 0.01 0.  ]
# Cheerful [0.83 0.13 0.02 0.01 0.01]
# Cheerful [0.77 0.19 0.01 0.01 0.02]
# Cheerful [0.79 0.17 0.01 0.01 0.02]
# Cheerful [0.76 0.21 0.   0.01 0.02]
# Cheerful [0.74 0.22 0.01 0.01 0.02]
# Cheerful [0.73 0.23 0.01 0.01 0.02]
# Cheerful [0.71 0.22 0.04 0.01 0.02]
# Cheerful [0.73 0.22 0.02 0.01 0.02]
# Cheerful [0.73 0.23 0.01 0.01 0.02]
# Cheerful [0.69 0.23 0.05 0.01 0.02]
# Cheerful [0.74 0.21 0.02 0.01 0.02]
# Cheerful [0.74 0.22 0.01 0.01 0.02]
# Cheerful [0.74 0.21 0.02 0.01 0.02]
# Cheerful [0.72 0.23 0.02 0.01 0.02]
# Cheerful [0.71 0.24 0.02 0.01 0.02]
# Cheerful [0.7  0.25 0.02 0.01 0.02]
# angry [0.41 0.49 0.05 0.   0.05]
# angry [0.17 0.76 0.03 0.   0.04]
# angry [0.09 0.9  0.   0.   0.01]
# angry [0.06 0.91 0.   0.   0.03]
# angry [0.02 0.89 0.   0.   0.09]
# angry [0.02 0.83 0.   0.   0.15]
# angry [0.02 0.84 0.   0.   0.14]
# angry [0.01 0.82 0.   0.   0.17]
# angry [0.02 0.82 0.   0.   0.16]
# angry [0.01 0.82 0.   0.   0.17]
# angry [0.01 0.81 0.   0.   0.18]
# angry [0.01 0.81 0.   0.   0.18]
# angry [0.01 0.81 0.   0.   0.18]
# angry [0.01 0.81 0.   0.   0.18]
# angry [0.02 0.82 0.   0.   0.16]
# angry [0.01 0.82 0.   0.   0.17]
# angry [0.01 0.83 0.   0.   0.16]
# angry [0.02 0.8  0.   0.   0.18]
# angry [0.02 0.82 0.   0.   0.16]
# angry [0.02 0.83 0.   0.   0.15]
# angry [0.01 0.83 0.   0.   0.16]
# angry [0.01 0.83 0.   0.   0.16]
# angry [0.01 0.78 0.   0.   0.21]
# angry [0.09 0.46 0.02 0.02 0.41]
# sad [0.27 0.18 0.09 0.15 0.31]
# inappropriate [0.29 0.02 0.11 0.51 0.07]
# inappropriate [0.29 0.03 0.06 0.54 0.08]
# inappropriate [0.32 0.03 0.17 0.38 0.1 ]
# inappropriate [0.32 0.04 0.18 0.35 0.11]
# Cheerful [0.31 0.08 0.15 0.3  0.16]
# Cheerful [0.3  0.08 0.16 0.29 0.17]
# Cheerful [0.3  0.07 0.17 0.27 0.19]
# Cheerful [0.29 0.1  0.15 0.25 0.21]
# Cheerful [0.28 0.1  0.15 0.26 0.21]
# sad [0.2  0.2  0.05 0.1  0.45]
# sad [0.18 0.2  0.08 0.1  0.44]
# Cheerful [0.32 0.06 0.17 0.27 0.18]
# sad [0.18 0.21 0.08 0.12 0.41]
# sad [0.2  0.24 0.05 0.07 0.44]
# sad [0.22 0.29 0.05 0.05 0.39]
# sad [0.22 0.28 0.05 0.05 0.4 ]
# sad [0.22 0.29 0.05 0.05 0.39]
# sad [0.19 0.32 0.05 0.05 0.39]
# angry [0.06 0.5  0.03 0.02 0.39]
# angry [0.05 0.52 0.03 0.02 0.38]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (353, 241)

# %%
video_path = 'test_video.mp4'
cap = cv2.VideoCapture(video_path)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        # Check if the video has ended
        if not ret:
            break

        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make Detections
        results = holistic.process(image)

        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
        
        # Display the processed frame
        cv2.imshow('Processed Video', image)

        # Check for the 'q' key to exit
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Cheerful [0.52 0.01 0.16 0.08 0.23]
# Cheerful [0.57 0.01 0.16 0.03 0.23]
# Cheerful [0.55 0.01 0.2  0.01 0.23]
# Cheerful [0.49 0.01 0.16 0.11 0.23]
# Cheerful [0.54 0.01 0.18 0.04 0.23]
# Cheerful [0.53 0.01 0.21 0.02 0.23]
# Cheerful [0.67 0.01 0.09 0.   0.23]
# Cheerful [0.55 0.01 0.21 0.   0.23]
# Cheerful [0.62 0.01 0.14 0.   0.23]
# Cheerful [0.51 0.01 0.24 0.   0.24]
# Cheerful [0.71 0.   0.07 0.   0.22]
# Cheerful [0.56 0.01 0.2  0.   0.23]
# Cheerful [0.54 0.01 0.22 0.   0.23]
# Cheerful [0.56 0.01 0.2  0.   0.23]
# Cheerful [0.69 0.01 0.06 0.02 0.22]
# Cheerful [0.69 0.   0.08 0.01 0.22]
# Cheerful [0.72 0.   0.06 0.   0.22]
# Cheerful [0.75 0.   0.03 0.   0.22]
# Cheerful [0.76 0.   0.02 0.   0.22]
# Cheerful [0.75 0.   0.03 0.   0.22]
# Cheerful [0.74 0.   0.03 0.   0.23]
# Cheerful [0.77 0.   0.02 0.   0.21]
# Cheerful [0.79 0.   0.   0.   0.21]
# Cheerful [0.77 0.   0.02 0.   0.21]
# Cheerful [0.79 0.   0.01 0.   0.2 ]
# Cheerful [0.79 0.   0.   0.01 0.2 ]
# Cheerful [0.73 0.   0.07 0.   0.2 ]
# Cheerful [0.74 0.   0.06 0.   0.2 ]
# Cheerful [0.77 0.01 0.1  0.01 0.11]
# Cheerful [0.71 0.01 0.12 0.03 0.13]
# Cheerful [0.55 0.01 0.25 0.06 0.13]
# Cheerful [0.49 0.   0.34 0.04 0.13]
# Cheerful [0.44 0.   0.39 0.05 0.12]
# Cheerful [0.39 0.   0.37 0.12 0.12]
# Cheerful [0.43 0.   0.4  0.06 0.11]
# Cheerful [0.45 0.   0.42 0.02 0.11]
# Cheerful [0.44 0.   0.43 0.02 0.11]
# Cheerful [0.4  0.   0.36 0.13 0.11]
# Cheerful [0.45 0.   0.38 0.06 0.11]
# Cheerful [0.42 0.   0.42 0.05 0.11]
# Cheerful [0.43 0.   0.41 0.05 0.11]
# confident [0.4  0.   0.42 0.06 0.12]
# Cheerful [0.44 0.   0.4  0.05 0.11]
# Cheerful [0.45 0.   0.38 0.05 0.12]
# Cheerful [0.44 0.   0.34 0.1  0.12]
# confident [0.32 0.   0.33 0.23 0.12]
# Cheerful [0.46 0.   0.38 0.04 0.12]
# Cheerful [0.44 0.   0.4  0.04 0.12]
# Cheerful [0.52 0.   0.33 0.03 0.12]
# Cheerful [0.52 0.   0.3  0.06 0.12]
# Cheerful [0.47 0.   0.36 0.05 0.12]
# Cheerful [0.53 0.   0.27 0.03 0.17]
# Cheerful [0.49 0.   0.3  0.04 0.17]
# Cheerful [0.51 0.   0.28 0.01 0.2 ]
# Cheerful [0.67 0.   0.12 0.01 0.2 ]
# Cheerful [0.71 0.   0.08 0.01 0.2 ]
# Cheerful [0.76 0.   0.04 0.   0.2 ]
# Cheerful [0.73 0.   0.06 0.   0.21]
# Cheerful [0.74 0.   0.06 0.   0.2 ]
# Cheerful [0.78 0.   0.02 0.   0.2 ]
# Cheerful [0.77 0.   0.02 0.   0.21]
# Cheerful [0.74 0.   0.05 0.   0.21]
# Cheerful [0.77 0.   0.02 0.   0.21]
# Cheerful [0.72 0.   0.08 0.   0.2 ]
# Cheerful [0.66 0.   0.12 0.01 0.21]
# Cheerful [0.56 0.   0.22 0.01 0.21]
# Cheerful [0.59 0.   0.25 0.01 0.15]
# Cheerful [0.54 0.01 0.26 0.01 0.18]
# Cheerful [0.51 0.   0.25 0.04 0.2 ]
# Cheerful [0.53 0.   0.26 0.   0.21]
# Cheerful [0.5  0.   0.2  0.09 0.21]
# Cheerful [0.44 0.   0.32 0.03 0.21]
# Cheerful [0.51 0.   0.27 0.03 0.19]
# Cheerful [0.48 0.   0.28 0.06 0.18]
# Cheerful [0.47 0.   0.28 0.07 0.18]
# Cheerful [0.45 0.   0.26 0.09 0.2 ]
# Cheerful [0.47 0.   0.29 0.06 0.18]
# Cheerful [0.49 0.   0.3  0.03 0.18]
# Cheerful [0.48 0.   0.37 0.02 0.13]
# Cheerful [0.45 0.   0.38 0.04 0.13]
# Cheerful [0.51 0.   0.37 0.02 0.1 ]
# Cheerful [0.5  0.   0.47 0.02 0.01]
# Cheerful [0.49 0.   0.49 0.02 0.  ]
# confident [0.44 0.   0.49 0.07 0.  ]
# confident [0.42 0.   0.56 0.02 0.  ]
# confident [0.42 0.   0.56 0.02 0.  ]
# confident [0.43 0.   0.54 0.02 0.01]
# confident [0.43 0.   0.53 0.03 0.01]
# confident [0.46 0.   0.51 0.02 0.01]
# Cheerful [0.53 0.   0.44 0.02 0.01]
# confident [0.44 0.   0.51 0.02 0.03]
# confident [0.45 0.   0.51 0.02 0.02]
# Cheerful [0.49 0.   0.48 0.02 0.01]
# confident [0.46 0.   0.51 0.02 0.01]
# confident [0.41 0.   0.54 0.02 0.03]
# confident [0.41 0.   0.54 0.02 0.03]
# confident [0.43 0.   0.52 0.02 0.03]
# confident [0.41 0.   0.55 0.02 0.02]
# confident [0.41 0.   0.55 0.03 0.01]
# confident [0.41 0.   0.54 0.03 0.02]
# confident [0.41 0.   0.55 0.02 0.02]
# confident [0.39 0.   0.56 0.03 0.02]
# confident [0.41 0.   0.53 0.04 0.02]
# confident [0.4  0.   0.53 0.04 0.03]
# confident [0.42 0.   0.53 0.03 0.02]
# confident [0.42 0.   0.53 0.03 0.02]
# confident [0.4  0.   0.54 0.04 0.02]
# confident [0.41 0.   0.54 0.03 0.02]
# confident [0.42 0.   0.52 0.04 0.02]
# confident [0.42 0.   0.53 0.03 0.02]
# confident [0.41 0.   0.53 0.04 0.02]
# confident [0.43 0.   0.53 0.02 0.02]
# confident [0.42 0.   0.53 0.03 0.02]
# confident [0.4  0.   0.54 0.04 0.02]
# confident [0.4  0.   0.54 0.04 0.02]
# confident [0.4  0.   0.56 0.02 0.02]
# confident [0.42 0.   0.53 0.03 0.02]
# confident [0.4  0.   0.55 0.03 0.02]
# confident [0.42 0.   0.54 0.02 0.02]
# confident [0.4  0.   0.56 0.02 0.02]
# confident [0.41 0.   0.52 0.03 0.04]
# confident [0.41 0.   0.53 0.02 0.04]
# confident [0.41 0.   0.56 0.03 0.  ]
# confident [0.41 0.   0.57 0.02 0.  ]
# confident [0.37 0.   0.54 0.02 0.07]
# confident [0.41 0.   0.53 0.02 0.04]
# confident [0.39 0.   0.5  0.01 0.1 ]
# confident [0.38 0.   0.53 0.01 0.08]
# confident [0.37 0.   0.47 0.03 0.13]
# confident [0.36 0.   0.42 0.03 0.19]
# Cheerful [0.4  0.   0.38 0.02 0.2 ]
# Cheerful [0.44 0.   0.4  0.01 0.15]
# Cheerful [0.48 0.02 0.24 0.01 0.25]
# sad [0.42 0.05 0.1  0.   0.43]
# sad [0.34 0.05 0.2  0.   0.41]
# Cheerful [0.5  0.07 0.05 0.   0.38]
# Cheerful [0.44 0.06 0.08 0.   0.42]
# sad [0.19 0.13 0.04 0.   0.64]
# sad [0.07 0.18 0.01 0.   0.74]
# sad [0.06 0.22 0.01 0.   0.71]
# sad [0.05 0.19 0.01 0.   0.75]
# sad [0.04 0.19 0.01 0.   0.76]
# sad [0.04 0.19 0.01 0.   0.76]
# sad [0.04 0.18 0.01 0.   0.77]
# sad [0.04 0.16 0.01 0.   0.79]
# sad [0.04 0.16 0.   0.   0.8 ]
# sad [0.04 0.15 0.   0.   0.81]
# sad [0.04 0.15 0.   0.   0.81]
# sad [0.04 0.15 0.   0.   0.81]
# sad [0.04 0.14 0.   0.   0.82]
# sad [0.04 0.14 0.   0.   0.82]
# sad [0.03 0.14 0.   0.   0.83]
# sad [0.02 0.13 0.   0.   0.85]
# sad [0.02 0.1  0.   0.   0.88]
# sad [0.02 0.1  0.   0.   0.88]
# sad [0.02 0.1  0.   0.   0.88]
# sad [0.01 0.11 0.   0.   0.88]
# sad [0.01 0.11 0.   0.   0.88]
# sad [0.01 0.11 0.   0.   0.88]
# sad [0.01 0.09 0.   0.   0.9 ]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.16 0.   0.   0.83]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.17 0.   0.   0.82]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.16 0.   0.   0.83]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.16 0.   0.   0.83]
# sad [0.01 0.17 0.   0.   0.82]
# sad [0.02 0.21 0.   0.   0.77]
# sad [0.03 0.34 0.   0.   0.63]
# sad [0.03 0.39 0.   0.   0.58]
# sad [0.03 0.4  0.01 0.   0.56]
# angry [0.02 0.48 0.02 0.   0.48]
# angry [0.02 0.49 0.   0.   0.49]
# sad [0.02 0.46 0.   0.   0.52]
# sad [0.01 0.46 0.   0.   0.53]
# sad [0.02 0.45 0.   0.   0.53]
# sad [0.02 0.44 0.   0.   0.54]
# sad [0.02 0.44 0.   0.   0.54]
# sad [0.01 0.45 0.   0.   0.54]
# sad [0.02 0.44 0.   0.   0.54]
# sad [0.01 0.45 0.   0.   0.54]
# sad [0.01 0.46 0.   0.   0.53]
# angry [0.  0.5 0.  0.  0.5]
# sad [0.01 0.48 0.   0.   0.51]
# sad [0.01 0.46 0.   0.   0.53]
# sad [0.01 0.42 0.   0.   0.57]
# sad [0.   0.43 0.   0.   0.57]
# sad [0.   0.43 0.   0.   0.57]
# sad [0.   0.44 0.   0.   0.56]
# sad [0.   0.44 0.   0.   0.56]
# sad [0.   0.45 0.   0.   0.55]
# sad [0.   0.45 0.   0.   0.55]
# sad [0.   0.43 0.   0.   0.57]
# sad [0.   0.43 0.   0.   0.57]
# sad [0.   0.46 0.   0.   0.54]
# sad [0.   0.47 0.   0.   0.53]
# sad [0.   0.45 0.   0.   0.55]
# sad [0.01 0.49 0.   0.   0.5 ]
# sad [0.   0.49 0.   0.   0.51]
# sad [0.   0.49 0.   0.   0.51]
# sad [0.   0.49 0.   0.   0.51]
# sad [0.   0.47 0.   0.   0.53]
# sad [0.   0.48 0.   0.   0.52]
# sad [0.   0.48 0.   0.   0.52]
# sad [0.   0.48 0.   0.   0.52]
# sad [0.01 0.47 0.   0.   0.52]
# sad [0.   0.48 0.   0.   0.52]
# sad [0.   0.48 0.   0.   0.52]
# sad [0.   0.48 0.   0.   0.52]
# angry [0.   0.51 0.   0.   0.49]
# angry [0.   0.52 0.   0.   0.48]
# angry [0.   0.53 0.   0.   0.47]
# angry [0.   0.53 0.   0.   0.47]
# sad [0.   0.49 0.   0.   0.51]
# sad [0.01 0.47 0.   0.   0.52]
# sad [0.   0.48 0.   0.   0.52]
# sad [0.   0.48 0.   0.   0.52]
# sad [0.   0.47 0.   0.   0.53]
# sad [0.   0.49 0.   0.   0.51]
# sad [0.   0.48 0.   0.   0.52]
# sad [0.   0.47 0.   0.   0.53]
# sad [0.01 0.45 0.   0.   0.54]
# sad [0.01 0.4  0.   0.   0.59]
# sad [0.01 0.36 0.   0.   0.63]
# sad [0.03 0.38 0.   0.   0.59]
# sad [0.04 0.37 0.   0.   0.59]
# sad [0.02 0.17 0.   0.   0.81]
# sad [0.02 0.17 0.   0.   0.81]
# sad [0.02 0.15 0.   0.   0.83]
# sad [0.02 0.15 0.   0.   0.83]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.16 0.   0.   0.83]
# sad [0.01 0.16 0.   0.   0.83]
# sad [0.01 0.16 0.   0.   0.83]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.13 0.   0.   0.86]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.15 0.   0.   0.84]
# sad [0.01 0.14 0.   0.   0.85]
# sad [0.01 0.17 0.   0.   0.82]
# sad [0.01 0.17 0.   0.   0.82]
# sad [0.01 0.21 0.   0.   0.78]
# sad [0.02 0.19 0.   0.   0.79]
# sad [0.02 0.2  0.   0.   0.78]
# sad [0.02 0.22 0.   0.   0.76]
# sad [0.02 0.24 0.   0.   0.74]
# sad [0.02 0.28 0.   0.   0.7 ]
# sad [0.04 0.24 0.   0.   0.72]
# sad [0.04 0.24 0.   0.   0.72]
# sad [0.04 0.3  0.   0.   0.66]
# sad [0.05 0.3  0.   0.   0.65]
# sad [0.02 0.32 0.   0.   0.66]
# sad [0.02 0.33 0.   0.   0.65]
# sad [0.04 0.28 0.   0.   0.68]
# sad [0.02 0.31 0.   0.   0.67]
# sad [0.04 0.27 0.   0.   0.69]
# sad [0.03 0.28 0.   0.   0.69]
# sad [0.02 0.29 0.   0.   0.69]
# sad [0.04 0.26 0.   0.   0.7 ]
# sad [0.02 0.29 0.   0.   0.69]
# sad [0.02 0.29 0.   0.   0.69]
# sad [0.03 0.29 0.   0.   0.68]
# sad [0.05 0.27 0.   0.   0.68]
# sad [0.03 0.28 0.   0.   0.69]
# sad [0.02 0.29 0.   0.   0.69]
# sad [0.02 0.29 0.   0.   0.69]
# sad [0.04 0.26 0.   0.   0.7 ]
# sad [0.03 0.28 0.   0.   0.69]
# sad [0.02 0.24 0.   0.   0.74]
# sad [0.02 0.24 0.   0.   0.74]
# sad [0.04 0.27 0.   0.   0.69]
# sad [0.02 0.25 0.   0.   0.73]
# sad [0.03 0.24 0.   0.   0.73]
# sad [0.05 0.27 0.   0.   0.68]
# sad [0.04 0.22 0.   0.   0.74]
# sad [0.06 0.15 0.   0.   0.79]
# sad [0.23 0.07 0.06 0.05 0.59]
# confident [0.24 0.01 0.28 0.19 0.28]
# confident [0.31 0.01 0.33 0.07 0.28]
# inappropriate [0.22 0.01 0.26 0.41 0.1 ]
# inappropriate [0.19 0.01 0.15 0.54 0.11]
# confident [0.21 0.01 0.39 0.26 0.13]
# confident [0.25 0.01 0.52 0.06 0.16]
# confident [0.24 0.05 0.47 0.   0.24]
# confident [0.24 0.07 0.41 0.   0.28]
# confident [0.2  0.02 0.57 0.   0.21]
# confident [0.2  0.02 0.57 0.   0.21]
# confident [0.22 0.04 0.53 0.   0.21]
# confident [0.19 0.02 0.56 0.   0.23]
# confident [0.19 0.02 0.55 0.   0.24]
# confident [0.19 0.02 0.56 0.   0.23]
# confident [0.21 0.02 0.53 0.   0.24]
# confident [0.21 0.02 0.53 0.   0.24]
# confident [0.21 0.04 0.51 0.   0.24]
# confident [0.21 0.04 0.5  0.   0.25]
# confident [0.21 0.04 0.5  0.   0.25]
# confident [0.22 0.02 0.52 0.   0.24]
# confident [0.21 0.04 0.5  0.   0.25]
# confident [0.21 0.07 0.37 0.   0.35]
# confident [0.22 0.07 0.4  0.   0.31]
# confident [0.22 0.07 0.37 0.   0.34]
# confident [0.21 0.08 0.38 0.   0.33]
# confident [0.21 0.07 0.38 0.   0.34]
# confident [0.21 0.07 0.38 0.   0.34]
# confident [0.22 0.07 0.38 0.   0.33]
# confident [0.2  0.06 0.44 0.   0.3 ]
# confident [0.21 0.04 0.52 0.   0.23]
# confident [0.22 0.06 0.46 0.   0.26]
# confident [0.22 0.05 0.5  0.   0.23]
# confident [0.22 0.04 0.49 0.   0.25]
# confident [0.23 0.02 0.57 0.   0.18]
# confident [0.23 0.02 0.56 0.   0.19]
# confident [0.31 0.06 0.58 0.   0.05]
# confident [0.29 0.04 0.64 0.   0.03]
# confident [0.28 0.02 0.68 0.   0.02]
# confident [0.26 0.02 0.7  0.   0.02]
# confident [0.26 0.02 0.7  0.   0.02]
# confident [0.28 0.02 0.68 0.   0.02]
# confident [0.25 0.   0.69 0.04 0.02]
# confident [0.24 0.   0.59 0.15 0.02]
# confident [0.26 0.   0.66 0.06 0.02]
# confident [0.26 0.   0.6  0.12 0.02]
# inappropriate [0.16 0.   0.08 0.73 0.03]
# inappropriate [0.18 0.   0.07 0.73 0.02]
# inappropriate [0.21 0.   0.18 0.59 0.02]
# inappropriate [0.18 0.   0.19 0.61 0.02]
# inappropriate [0.27 0.   0.27 0.43 0.03]
# inappropriate [0.22 0.   0.25 0.53 0.  ]
# inappropriate [0.24 0.   0.22 0.54 0.  ]
# inappropriate [0.19 0.   0.05 0.76 0.  ]
# inappropriate [0.26 0.01 0.22 0.51 0.  ]
# inappropriate [0.28 0.01 0.13 0.54 0.04]
# Cheerful [0.55 0.01 0.22 0.07 0.15]
# Cheerful [0.59 0.01 0.18 0.07 0.15]
# Cheerful [0.79 0.   0.04 0.02 0.15]
# Cheerful [0.71 0.   0.12 0.01 0.16]
# Cheerful [0.7  0.01 0.1  0.   0.19]
# Cheerful [0.74 0.   0.07 0.   0.19]
# Cheerful [0.61 0.   0.2  0.   0.19]
# Cheerful [0.61 0.   0.22 0.   0.17]
# Cheerful [0.57 0.   0.25 0.01 0.17]
# Cheerful [0.55 0.   0.25 0.02 0.18]
# Cheerful [0.57 0.   0.27 0.02 0.14]
# Cheerful [0.48 0.   0.38 0.01 0.13]
# Cheerful [0.47 0.   0.37 0.03 0.13]
# confident [0.39 0.   0.45 0.01 0.15]
# confident [0.33 0.   0.53 0.   0.14]
# confident [0.31 0.   0.54 0.   0.15]
# confident [0.26 0.05 0.49 0.   0.2 ]
# confident [0.25 0.07 0.42 0.   0.26]
# confident [0.26 0.08 0.37 0.   0.29]
# sad [0.2  0.18 0.28 0.   0.34]
# sad [0.17 0.27 0.23 0.   0.33]
# confident [0.25 0.16 0.34 0.   0.25]
# confident [0.24 0.1  0.39 0.   0.27]
# confident [0.25 0.09 0.41 0.   0.25]
# confident [0.26 0.09 0.46 0.   0.19]
# confident [0.22 0.03 0.65 0.   0.1 ]
# confident [0.25 0.02 0.65 0.   0.08]
# confident [0.25 0.02 0.66 0.   0.07]
# confident [0.26 0.02 0.66 0.   0.06]
# confident [0.25 0.02 0.66 0.   0.07]
# confident [0.27 0.02 0.66 0.   0.05]
# confident [0.25 0.02 0.64 0.   0.09]
# confident [0.25 0.07 0.56 0.   0.12]
# confident [0.23 0.13 0.44 0.   0.2 ]
# confident [0.23 0.23 0.34 0.   0.2 ]
# confident [0.27 0.16 0.49 0.   0.08]
# confident [0.36 0.11 0.5  0.   0.03]
# confident [0.31 0.03 0.66 0.   0.  ]
# confident [0.26 0.   0.73 0.01 0.  ]
# confident [0.28 0.   0.67 0.05 0.  ]
# confident [0.28 0.   0.49 0.23 0.  ]
# inappropriate [0.19 0.   0.1  0.71 0.  ]
# inappropriate [0.23 0.   0.18 0.59 0.  ]
# Cheerful [0.62 0.   0.23 0.14 0.01]
# Cheerful [0.51 0.   0.14 0.15 0.2 ]
# Cheerful [0.64 0.   0.11 0.06 0.19]
# Cheerful [0.74 0.   0.04 0.01 0.21]
# Cheerful [0.8 0.  0.  0.  0.2]
# Cheerful [0.83 0.   0.   0.   0.17]
# Cheerful [0.81 0.   0.   0.   0.19]
# Cheerful [0.8 0.  0.  0.  0.2]
# Cheerful [0.81 0.   0.   0.   0.19]
# Cheerful [0.85 0.   0.   0.   0.15]
# Cheerful [0.85 0.   0.   0.   0.15]
# Cheerful [0.85 0.   0.   0.   0.15]
# Cheerful [0.83 0.   0.01 0.01 0.15]
# Cheerful [0.8  0.   0.05 0.   0.15]
# Cheerful [0.86 0.   0.03 0.   0.11]
# Cheerful [0.72 0.   0.17 0.04 0.07]
# Cheerful [0.4  0.   0.18 0.35 0.07]
# inappropriate [0.25 0.   0.14 0.55 0.06]
# Cheerful [0.49 0.   0.24 0.27 0.  ]
# inappropriate [0.33 0.   0.25 0.42 0.  ]
# Cheerful [0.45 0.   0.36 0.19 0.  ]
# inappropriate [0.27 0.   0.21 0.52 0.  ]
# inappropriate [0.29 0.   0.24 0.47 0.  ]
# Cheerful [0.35 0.   0.31 0.34 0.  ]
# inappropriate [0.25 0.   0.16 0.59 0.  ]
# Cheerful [0.42 0.   0.21 0.35 0.02]
# Cheerful [0.6  0.   0.16 0.1  0.14]
# inappropriate [0.28 0.   0.11 0.42 0.19]
# Cheerful [0.48 0.   0.11 0.19 0.22]
# Cheerful [0.65 0.   0.09 0.06 0.2 ]
# Cheerful [0.69 0.   0.05 0.06 0.2 ]
# Cheerful [0.76 0.01 0.02 0.01 0.2 ]
# Cheerful [0.72 0.01 0.03 0.04 0.2 ]
# Cheerful [0.77 0.   0.02 0.01 0.2 ]
